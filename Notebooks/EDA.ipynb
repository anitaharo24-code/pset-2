# %%
import pandas as pd

# %%
# código para cargar un archivo parquet desde internet
# necesito cargar datos de todos los meses de 2025, pero por ahora solo cargo el de enero para probar
# url mes enero 2025
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-01.parquet"
df = pd.read_parquet(url)

# %%
df.columns=[columna.lower() for columna in df.columns]
df.head()
# Out:
#    vendorid lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-01-01 00:03:01   2025-01-01 00:17:12                  N
# 1         2  2025-01-01 00:19:59   2025-01-01 00:25:52                  N
# 2         2  2025-01-01 00:05:29   2025-01-01 00:07:21                  N
# 3         2  2025-01-01 00:52:24   2025-01-01 01:07:52                  N
# 4         2  2025-01-01 00:25:05   2025-01-01 01:01:10                  N
#
#    ratecodeid  pulocationid  dolocationid  passenger_count  trip_distance  \
# 0         1.0            75           235              1.0           5.93
# 1         1.0           166            75              1.0           1.32
# 2         5.0           171            73              1.0           0.41
# 3         1.0            74           223              1.0           4.12
# 4         1.0            66           158              1.0           4.71
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
#Cambiar nombre de columnas con palabras unidas por guion bajo
df.rename(columns={'vendorid': 'vendor_id', 'ratecodeid': 'rate_code_id', 'pulocationid': 'pu_location_id', 'dolocationid': 'do_location_id'},inplace=True)
df.head()
# Out:
#    vendor_id lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0          2  2025-01-01 00:03:01   2025-01-01 00:17:12                  N
# 1          2  2025-01-01 00:19:59   2025-01-01 00:25:52                  N
# 2          2  2025-01-01 00:05:29   2025-01-01 00:07:21                  N
# 3          2  2025-01-01 00:52:24   2025-01-01 01:07:52                  N
# 4          2  2025-01-01 00:25:05   2025-01-01 01:01:10                  N
#
#    rate_code_id  pu_location_id  do_location_id  passenger_count  \
# 0           1.0              75             235              1.0
# 1           1.0             166              75              1.0
# 2           5.0             171              73              1.0
# 3           1.0              74             223              1.0
# 4           1.0              66             158              1.0
#
#    trip_distance  fare_amount  ...  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
import pandas as pd
import os

"""
Template code for loading data from any source.

    Returns:
        Anything (e.g. data frame, dictionary, array, int, str, etc.)
"""
year = 2025
months = [1, 2]  # Enero y Febrero como prueba

base_columns = None
all_chunks = []

for month in months:
    url = f'https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_{year}-{month:02d}.parquet'
# Leer parquet directamente desde la URL
    df = pd.read_parquet(url)

 
    for chunk in load_parquet_in_chunks(df):
        all_chunks.append(chunk)

        print(f'Mes {month} cargado.')
 
all_chunks# Specify your data loading logic here
# Out:
# Mes 1 cargado.
# Mes 2 cargado.
# [       VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
#  0             2  2025-01-01 00:03:01   2025-01-01 00:17:12                  N
#  1             2  2025-01-01 00:19:59   2025-01-01 00:25:52                  N
#  2             2  2025-01-01 00:05:29   2025-01-01 00:07:21                  N
#  3             2  2025-01-01 00:52:24   2025-01-01 01:07:52                  N
#  4             2  2025-01-01 00:25:05   2025-01-01 01:01:10                  N
#  ...         ...                  ...                   ...                ...
#  48321         2  2025-01-31 19:36:00   2025-01-31 20:05:00               None
#  48322         2  2025-01-31 20:33:00   2025-01-31 20:41:00               None
#  48323         2  2025-01-31 21:09:00   2025-01-31 21:30:00               None
#  48324         2  2025-01-31 22:22:00   2025-01-31 22:25:00               None
# ...

# %%
type(all_chunks)
data= pd.concat(all_chunks, ignore_index=True)
print(type(data))
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-01-01 00:03:01   2025-01-01 00:17:12                  N
# 1         2  2025-01-01 00:19:59   2025-01-01 00:25:52                  N
# 2         2  2025-01-01 00:05:29   2025-01-01 00:07:21                  N
# 3         2  2025-01-01 00:52:24   2025-01-01 01:07:52                  N
# 4         2  2025-01-01 00:25:05   2025-01-01 01:01:10                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            75           235              1.0           5.93
# 1         1.0           166            75              1.0           1.32
# 2         5.0           171            73              1.0           0.41
# 3         1.0            74           223              1.0           4.12
# 4         1.0            66           158              1.0           4.71
#
# ...
